# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %%
dataset= pd.read_csv("/diabetes.csv")
df= dataset.copy()

# %%
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
peek= df.shape
print(peek)
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
sns.countplot(x='Outcome'   , data=df )

# %% [markdown]
# Analyse de la  variable target outcome: on constate que presque 250personnes sont diabetiques. .65,1042 ne sont pas diabetiques et 34,8958 sont diabetiques

# %%
df['Outcome'].value_counts(normalize= True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# on constate aucune valeur manquante.

# %% [markdown]
# DESCRIPTION DE DONNES
#
# The datasets consists of several medical predictor variables and one target variable, Outcome. Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %%
sns.boxplot(x='Outcome', y='DiabetesPedigreeFunction', data=df)

# %% [markdown]
# Analyse de la variable target/DiabetesPedigreeFunction: l'obtention rapide du diabete pourrait lie a  la desecndance

# %%
sns.boxplot(x='Outcome', y='BMI', data=df)

# %% [markdown]
# Analyse de la variable target outcome/Bmi: les personnes diabetiques ont un Bmi tres eleve

# %%
sns.boxplot(x='Outcome', y='', data=df)

# %% [markdown]
# ```
# # `Ce texte est au format code`
# ```
#
# Analyse de la variabale target Outcome/BloodPressurre : les gens qui sont diabetiques ont un  BloodPressurre tres eleve.

# %%
sns.boxplot(x='Glucose',data=df)

# %%
sns.countplot(x='Insulin' ,data=df)

# %%
sns.boxplot(x='Outcome', y='Pregnancies', data=df)

# %% [markdown]
# Analyse dela variable target outcome/pregnancies: personnes diabetiques ont une phase pregnancies ters longue

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.hist()
pyplot.show()

# %%
df.plot(kind='density',subplots=True,layout=(3,3),sharex=False)
pyplot.show()

# %% [markdown]
# Analyse de variable:
# Relatiion Glucose/insuline: on constate que  une forte correlation. ainsi on peut retenir que le taux  de glucose depend du taux d'insuline.
# Relation glucose/bloodpressure: le glucose determine  le taux de bloodpressure
# Relation age/bmi: forte correlation

# %% [markdown]
# DATACLEANING

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
dups=df.duplicated()
print(dups.any())
print(df[dups])
# Out:
# False
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []
